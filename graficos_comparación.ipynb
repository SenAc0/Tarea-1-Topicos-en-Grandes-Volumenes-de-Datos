# %%
import matplotlib.pyplot as plt
import numpy as np

# --------- Tower Sketch ---------


tower_k21_mae = [0.423259, 0.170068, 0.0768123, 0.0474547]
tower_k21_mre = [0.420786, 0.168521, 0.075638, 0.0464104]
tower_k21_labels = [
    "w={1.2M,0.6M,0.3M,0.1M}\nb={8,16,32,64}\nd=4",
    "w={1.5M,0.75M,0.375M,0.15M}\nb={8,16,32,64}\nd=6",
    "w={1.8M,0.9M,0.45M,0.2M}\nb={8,16,32,64}\nd=8",
    "w={2M,1M,0.5M,0.25M}\nb={8,16,32,64}\nd=10"
]


tower_k31_mae = [ 0.436539, 0.183637,  0.0906608, 0.0613058]
tower_k31_mre = [0.434211, 0.182132,  0.0894869, 0.060252]
tower_k31_labels = tower_k21_labels

# Gráfico Tower K21
x = np.arange(len(tower_k21_labels))
width = 0.35

fig, ax = plt.subplots(figsize=(10,7))
ax.bar(x - width/2, tower_k21_mae, width, label="MAE")
ax.bar(x + width/2, tower_k21_mre, width, label="MRE")

# líneas de referencia
ax.axhline(min(tower_k21_mae), color='blue', linestyle='--', label='min MAE')
ax.axhline(min(tower_k21_mre), color='orange', linestyle='--', label='min MRE')

ax.set_xticks(x)
ax.set_xticklabels(tower_k21_labels)
ax.set_ylabel("Error")
ax.set_title("Tower Sketch K21")
ax.legend(loc="upper right")
plt.tight_layout()
plt.savefig("tower_sketch_k21_comparison.png", dpi=300)
plt.show()

# Gráfico Tower K31
x = np.arange(len(tower_k31_labels))
fig, ax = plt.subplots(figsize=(10,7))
ax.bar(x - width/2, tower_k31_mae, width, label="MAE")
ax.bar(x + width/2, tower_k31_mre, width, label="MRE")

ax.axhline(min(tower_k31_mae), color='blue', linestyle='--', label='min MAE')
ax.axhline(min(tower_k31_mre), color='orange', linestyle='--', label='min MRE')

ax.set_xticks(x)
ax.set_xticklabels(tower_k31_labels)
ax.set_ylabel("Error")
ax.set_title("Tower Sketch K31")
ax.legend(loc="upper right")
plt.tight_layout()
plt.savefig("tower_sketch_k31_comparison.png", dpi=300)
plt.show()

# --------- Count Sketch ---------
count_k21_mae = [1.34435,0.796144,0.481997,0.235538]
count_k21_mre = [1.33892,0.792577,0.479539,0.233902]
count_k21_labels = ["w=250k,d=4","w=500k,d=6","w=1M,d=8","w=2M,d=10"]

count_k31_mae = [1.35418,0.807175,0.49396,0.248491]
count_k31_mre = [1.34966,0.804137,0.4918,0.246958]
count_k31_labels = ["w=250k,d=4","w=500k,d=6","w=1M,d=8","w=2M,d=10"]

# Gráfico Count K21
x = np.arange(len(count_k21_labels))
fig, ax = plt.subplots(figsize=(10,7))
ax.bar(x - width/2, count_k21_mae, width, label="MAE")
ax.bar(x + width/2, count_k21_mre, width, label="MRE")

ax.axhline(min(count_k21_mae), color='blue', linestyle='--', label='min MAE')
ax.axhline(min(count_k21_mre), color='orange', linestyle='--', label='min MRE')

ax.set_xticks(x)
ax.set_xticklabels(count_k21_labels, rotation=20)
ax.set_ylabel("Error")
ax.set_title("Count Sketch K21")
ax.legend(loc="upper right")
plt.tight_layout()
plt.savefig("count_sketch_k21_comparison.png", dpi=300)
plt.show()

# Gráfico Count K31
x = np.arange(len(count_k31_labels))
fig, ax = plt.subplots(figsize=(10,7))
ax.bar(x - width/2, count_k31_mae, width, label="MAE")
ax.bar(x + width/2, count_k31_mre, width, label="MRE")

ax.axhline(min(count_k31_mae), color='blue', linestyle='--', label='min MAE')
ax.axhline(min(count_k31_mre), color='orange', linestyle='--', label='min MRE')

ax.set_xticks(x)
ax.set_xticklabels(count_k31_labels, rotation=20)
ax.set_ylabel("Error")
ax.set_title("Count Sketch K31")
ax.legend(loc="upper right")
plt.tight_layout()
plt.savefig("count_sketch_k31_comparison.png", dpi=300)
plt.show()
